# %%
import nbformat
from IPython import get_ipython
from IPython.core.interactiveshell import InteractiveShell
import re
import pandas as pd
from datetime import datetime

def run_notebook(notebook_path):
    with open(notebook_path) as f:
        nb = nbformat.read(f, as_version=4)
    shell = InteractiveShell.instance()
    for cell in nb.cells:
        if cell.cell_type == 'code':
            shell.run_cell(cell.source)
# run_notebook('BBC_amh_data_scratping.ipynb')
# run_notebook('Eth_Insider.ipynb')

# %%
amharic_df = pd.concat([df_bbc, df_eth], ignore_index=True)

# %%
amharic_df
# Out:
#            Date           Website  \
# 0    2024-05-25   www.bbc/amharic
# 1    2024-05-25   www.bbc/amharic
# 2    2024-05-25   www.bbc/amharic
# 3    2024-05-25   www.bbc/amharic
# 4    2024-05-25   www.bbc/amharic
# ..          ...               ...
# 101  2024-05-25  ethiopiainsider/
# 102  2024-05-25  ethiopiainsider/
# 103  2024-05-25  ethiopiainsider/
# 104  2024-05-25  ethiopiainsider/
# 105  2024-05-25  ethiopiainsider/
#
#                                                Article  \
# 0    ቻይና እና ሩሲያ ተፅእኗቸውን እያጠናከሩ ባሉባት አፍሪካ አሜሪካ ወዳጆቿን...
# 1    ©  ቢቢሲ ከሌሎች ድረገፆች ለሚመጡ መረጃዎች ሀላፊነት አይወስድምስለ ውጪ...
# 2    የፎቶው ባለመብት ኬንያ የሰሜን አትላንቲን ጦር ቃልኪዳን ድርጅት ኔቶ አባ...
# 3    የፎቶው ባለመብት   በዚህ ሳምንት መጀመሪያ ላይ በተለያዩ ማሀበራዊ ሚዲያ...
# 4    የፎቶው ባለመብት በሱዳን ዳርፉር ግዛት የዘር ማጥፋት እያንዣበበ ቢሆንም ...
# ..                                                 ...
# 101  በሰለሞን በርሀ ለሁለት አመታት በትግራይ ክልል በተካሄደው ጦርነት ወቅት ...
# 102  የኢትዮጵያ አገራዊ የምክክር ኮሚሽን የማቋቋሚያ አዋጅ በህዝብ ተወካዮች ም...
# 103  በናሆም አየለ የኢትዮጵያ ሀገራዊ ምክክር ኮሚሽን በሀገራዊ ምክክር ላይ አ...
# 104  በናሆም አየለ በኢትዮጵያ ካሉ 1300 ወረዳዎች መካከል በ850ዎቹ የምክክ...
# 105  በተስፋለም ወልደየስ በኢትዮጵያ ካሉ ወረዳዎች መካከል 327 የሚሆኑት በሀ...
#
#                                                  links
# 0                          https://www.bbc.com/amharic
# 1      https://www.bbc.com/amharic/topics/c7zp57r92v5t
# 2    https://www.bbc.com/amharic/articles/cyee975r989o
# 3    https://www.bbc.com/amharic/articles/c999lygqz7vo
# 4    https://www.bbc.com/amharic/articles/c888v82k4ygo
# ..                                                 ...
# 101            https://ethiopiainsider.com/2024/12937/
# 102  https://ethiopiainsider.com/%e1%8b%a8%e1%8a%a2...
# 103            https://ethiopiainsider.com/2024/13001/
# 104            https://ethiopiainsider.com/2024/12906/
# 105            https://ethiopiainsider.com/2023/12218/
#
# [106 rows x 4 columns]
